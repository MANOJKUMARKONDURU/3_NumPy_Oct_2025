# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/3_NumPy_Oct_2025/blob/main/03_NumPy%20ufuncs%20-%20oct04%20-%20oct06_2025/09_Finding_LCM_ufunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Finding LCM(Lowest Common Multiple)
#
# The Lowest Common Multiple is the smallest number that is a common multiple of two numbers

# %%
import numpy as np

# %%
num1 = 4
num2 = 8

x = np.lcm(num1, num2)

print(x)
# Out:
# 8

# %% [markdown]
# #Finding LCM in Arrays - **reduce()
#
# To find the Lowest common Multiple of all values in an array, you can use the **reduce()** method.
#
#
# ```
# np.lcm.reduce(array_name)
# ```

# %%
arr = np.array([4, 7, 8])

newarr = np.lcm.reduce(arr)
print(newarr)
# Out:
# 56

# %% [markdown]
# Lcm of all values of an array where the array contains all integers from 1 to 10

# %%
arr = np.arange(1, 11)

x = np.lcm.reduce(arr)
print(x)
# Out:
# 2520
