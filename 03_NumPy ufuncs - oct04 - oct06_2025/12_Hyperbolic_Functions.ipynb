# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/3_NumPy_Oct_2025/blob/main/03_NumPy%20ufuncs%20-%20oct04%20-%20oct06_2025/12_Hyperbolic_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hyperbolic Functions
#
# Just like sine and cosine relate to a circle, sinh (hyperbolic sine) and cosh (hyperbolic cosine) relate to a hyperbola.
#
# Where e(Euler's Number) ~= 2.71828
#
# 1.  sinh(x) =  ((e) ** (x) - (e) ** (-x)) / 2
# 2.  cosh(x) =  ((e) ** (x) + (e) ** (-x)) / 2
# 3.  tanh(x) =  sinh(x) / cosh(x)
#
#
#
# NumPy provides the ufuncss **sinh(), cosh(), tanh()** that takes values in radians and produce the corresponding sinh, cosh, tanh values.

# %%
import numpy as np

# %%
x = np.sinh(np.pi/2)
print(x)

y = np.tanh(np.pi/2)
print(y)
# Out:
# 2.3012989023072947
# 0.9171523356672744

# %% [markdown]
# #Find cosh values for all the values in array

# %%
arr = np.array([np.pi/2, np.pi/3, np.pi/4, np.pi/5])
x = np.cosh(arr)
print(x)
# Out:
# [2.50917848 1.60028686 1.32460909 1.20397209]

# %% [markdown]
# #Finding Angles
# Numpy provides ufuncs arcsinh(), arccosh() and arctanh() that produce radian values for corresponding sinh, cosh and tanh values given.
#
# ---
# Find the angle of 1.0:

# %%
x = np.arcsinh(1.0)
print(x)
# Out:
# 0.881373587019543

# %% [markdown]
# Find the angle for all the tanh values in array:

# %%
arr = np.array([0.1, 0.2, 0.5])
x = np.arctanh(arr)
print(x)
# Out:
# [0.10033535 0.20273255 0.54930614]
