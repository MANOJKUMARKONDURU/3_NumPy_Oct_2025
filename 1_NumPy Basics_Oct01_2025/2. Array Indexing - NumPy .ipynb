# %% [markdown]
# #Access Array Elements
# Array indexing is the same as accessing an array element
# *   You can access any array element by refering to its index number
# *   **The indexes in NumPy starts with 0**

# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4])
print(arr[0])
print(f"Second element is {arr[1]}")
# Out:
# 1
# Second element is 2

# %% [markdown]
# #Access 2-D Arrays
#
# **arr[dimension,index]**

# %%
arr = np.array([[1, 2, 3, 4, 5], [7, 8, 9, 10, 11]])

print(f"First element from the second dimension is {arr[1,0]}")

print(f"Second element from the first dimension is {arr[0, 1]}")
# Out:
# First element from the second dimension is 7
# Second element from the first dimension is 2

# %% [markdown]
# #Access 3-D Arrays
# We can use comma seperated integerd representing the dimensions and the index of the element

# %%
arr = np.array([ [[1, 2, 3], [4, 5, 7]], [ [8, 9, 10], [11, 12, 13]] ])
print(arr[0, 1, 2])

print(f"First element form the second dimension is {arr[1, 0, 0]}")
# Out:
# 7
# First element form the second dimension is 8

# %% [markdown]
# #Negative Indexing
#
# To access array from the end

# %%
print(f"last element of the array: {arr[1, 1, -1]}")
# Out:
# last element of the array: 13
