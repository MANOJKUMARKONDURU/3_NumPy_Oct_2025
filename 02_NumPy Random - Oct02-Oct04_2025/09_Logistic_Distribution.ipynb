# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/3_NumPy_Oct_2025/blob/main/02_NumPy%20Random%20-%20Oct02-Oct04_2025/09_Logistic_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Logistic Distribution
#
# Is used to describe growth.
#
# Used extensively in meachine learning in Logistic regression, neural networks etc.
#
# It has Three parameters.
#
# 1.  **loc** - mean, where the peak is. - Default 0.
#
# 2.  **scale** - standard deviation, the flatness of the distribution. Default 1.
#
# 3. **size** - The shape of the returned array.
#
#
#
# **Standard Deviation (σ)**
#
# Standard deviation tells us how spread out the data is from the mean.
#
# A low standard deviation → data points are close to the mean.
#
# A high standard deviation → data points are spread out widely.

# %%
from numpy import random

# %%
x = random.logistic(loc = 1, scale = 2, size = (2, 3))
print(x)
# Out:
# [[-0.66012898  1.91272876  3.47191492]
#  [ 0.22883502 -6.80675505  3.79458784]]

# %% [markdown]
# #Visuvalization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(random.logistic(size = 1000), kind = 'kde')
plt.show()

# %% [markdown]
# # Difference between Normal and Logistic Distribution
#
# Both are near Identical,  but logistic distribution has more area under the tails, meaning it represents more possibility of occurrence of an event further away from mean.
#
# For higher value of scale(standard deviation)  the normal and logistic distributions are near identical apart from the peak

# %%
data = {
    'Normal' : random.normal(scale = 2, size = 1000),
    'Logistic' : random.logistic(size = 1000)
}
sns.displot(data, kind = 'kde')
plt.show()
